# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanyadavcoder/python-prectice--basic/blob/main/OOP_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1,2,3,4]
print(type(l))
# Out:
# <class 'list'>

# %%
# pascal case
HelloWold

# %%
class Student:
  def show(self):
    print(self.name,self.marks)
s1 = Student()
s1.name = 'Aryan'
s1.marks = 89
s1.show()
# Out:
# Aryan 89

# %%
student1_name = "Ravi"
student1_marks = 85

student2_name = "Anita"
student2_marks = 92

def show_student(name, marks):
    print(name, marks)

show_student(student1_name, student1_marks)
show_student(student2_name, student2_marks)
# Out:
# Ravi 85
# Anita 92

# %%
class Atm:

    def __init__(self):
        self.pin = ""
        self.balance = 0
        self.menu()

    def menu(self):
        user_input = input("""
Hi how can I help you?

1. Press 1 to create pin
2. Press 2 to change pin
3. Press 3 to check balance
4. Press 4 to withdraw
5. Anything else to exit

""")

        if user_input == "1":
            self.create_pin()

        elif user_input == "2":
            self.change_pin()

        elif user_input == "3":
            self.check_balance()
            self.menu()

        elif user_input == "4":
            self.withdraw()

        else:
            print("Thank You")
            exit()

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        self.pin = user_pin

        user_balance = int(input("Enter balance: "))
        self.balance = user_balance

        print("Pin created successfully")
        self.menu()

    def change_pin(self):
        old_pin = input("Enter your old pin: ")

        if old_pin == self.pin:
            new_pin = input("Enter your new pin: ")
            self.pin = new_pin
            print("Pin changed successfully")
        else:
            print("Wrong old pin")
        self.menu()

    def check_balance(self):
      user_pin = input("Enter your pin: ")
      if user_pin == self.pin:
        print("your bank_balance is ",self.balance)
      else:
        print("your pin is wronge")

    def withdraw(self):
      user_pin = input("Enter your pin: ")
      if user_pin == self.pin:
        amount = int(input("Enter your withdrow amount: "))
        if amount <= self.balance:
          self.balance = self.balance - amount
          print("Withdrawl successful balance is ----> ",self.balance)
        else:
          print("balance nehi hai utna")
      else:
        print("your pin is not define")
        self.menu()

obj = Atm()
# Out:
# Hi how can I help you?
#
# 1. Press 1 to create pin
# 2. Press 2 to change pin
# 3. Press 3 to check balance
# 4. Press 4 to withdraw
# 5. Anything else to exit
#
# 1
# Enter your pin: 123
# Enter balance: 10000
# Pin created successfully
#
# Hi how can I help you?
#
# 1. Press 1 to create pin
# 2. Press 2 to change pin
# 3. Press 3 to check balance
# 4. Press 4 to withdraw
# 5. Anything else to exit
#
# 3
# Enter your pin: 123
# your bank_balance is  10000
#
# Hi how can I help you?
#
# 1. Press 1 to create pin
# 2. Press 2 to change pin
# 3. Press 3 to check balance
# 4. Press 4 to withdraw
# 5. Anything else to exit
#
# 4
# Enter your pin: 123
# Enter your withdrow amount: 5000
# Withdrawl successful balance is ---->  5000

# %% [markdown]
# **Magic Methods  or  A.k.a  Dundar Methods**
#
# ---
